# %%
import networkx as nx
import pandas as pd
import numpy as np
import itertools
import os

import matplotlib.pyplot as plt

import stellargraph as sg
from stellargraph.data import EdgeSplitter
from stellargraph.mapper import GraphSAGELinkGenerator
from stellargraph.layer import GraphSAGE, link_classification
from stellargraph.calibration import expected_calibration_error, plot_reliability_diagram
from stellargraph.calibration import IsotonicCalibration, TemperatureCalibration
from stellargraph import StellarGraph

from tensorflow import keras
from sklearn import preprocessing, feature_extraction, model_selection
from sklearn.calibration import calibration_curve
from sklearn.isotonic import IsotonicRegression

from sklearn.metrics import accuracy_score

from stellargraph import globalvar
from stellargraph import datasets
from IPython.display import display, HTML

# %matplotlib inline

# %%
batch_size = 50
epochs = 20  # The number of training epochs for training the GraphSAGE model.

# %%
playlist_nodes = pd.read_csv('D:\\extracted_features\\playlists_256_full.csv')
playlist_nodes = playlist_nodes.set_index('pid')
playlist_nodes
# Out:
#               0         1         2         3         4         5         6  \
# pid
# 0      0.548065 -0.004969 -0.152679  0.616827  0.274475  0.976250 -0.902120
# 1      0.546270 -0.033351 -0.392608  0.468498  0.234031  0.957838 -0.913424
# 2      0.253194 -0.020886 -0.405861  0.620173  0.321243  0.968687 -0.886844
# 3      0.387236 -0.055463 -0.166385  0.481297  0.278856  0.972705 -0.885096
# 4      0.570883 -0.019489 -0.218323  0.646070  0.287380  0.965244 -0.866297
# ...         ...       ...       ...       ...       ...       ...       ...
# 14995  0.509209 -0.032868 -0.259281  0.576987  0.271568  0.977360 -0.913212
# 14996  0.532920  0.023744 -0.080581  0.642182  0.273193  0.974883 -0.890937
# 14997  0.438527  0.008225 -0.064779  0.618701  0.240719  0.973851 -0.883567
# 14998  0.579338 -0.052516 -0.360727  0.458734  0.264151  0.979575 -0.924249
# 14999  0.458755 -0.007124 -0.355597  0.657200  0.303187  0.975179 -0.885570
#
#               7         8         9  ...       246       247       248  \
# pid                                  ...
# 0      0.046461 -0.536994  0.020827  ... -0.113749 -0.910833  0.997328
# 1      0.029962 -0.517722  0.039464  ... -0.086244 -0.909943  0.995852
# 2      0.061407 -0.320926  0.023277  ... -0.104075 -0.907041  0.993235
# 3      0.059435 -0.443821  0.010571  ... -0.107550 -0.914139  0.993060
# 4      0.019621 -0.610707  0.014086  ... -0.085111 -0.889409  0.996961
# ...         ...       ...       ...  ...       ...       ...       ...
# 14995  0.061560 -0.450586  0.038395  ... -0.120194 -0.904451  0.996007
# 14996  0.028100 -0.318348  0.036292  ... -0.128532 -0.891057  0.996765
# 14997  0.035740 -0.477776  0.058208  ... -0.120472 -0.915622  0.996209
# 14998  0.046682 -0.514681  0.025852  ... -0.082898 -0.879444  0.997280
# 14999  0.039809 -0.288600  0.042030  ... -0.111689 -0.903851  0.995959
#
#             249       250       251       252       253       254       255
# pid
# 0     -0.815965 -0.784344 -0.776490 -0.995361  0.768619  0.870750  0.010204
# 1     -0.778645 -0.843372 -0.733728 -0.996370  0.646433  0.860160  0.056390
# 2     -0.916639 -0.735473 -0.806277 -0.994427  0.797605  0.815965  0.025856
# 3     -0.819462 -0.833836 -0.794985 -0.994906  0.583700  0.758970  0.022974
# 4     -0.819861 -0.806127 -0.684427 -0.995705  0.726435  0.890715 -0.050058
# ...         ...       ...       ...       ...       ...       ...       ...
# 14995 -0.853962 -0.829651 -0.785840 -0.994907  0.715587  0.847042  0.020912
# 14996 -0.848702 -0.856475 -0.793554 -0.993932  0.639508  0.766159  0.043139
# 14997 -0.861927 -0.823383 -0.751569 -0.996538  0.701738  0.850584  0.037790
# 14998 -0.776388 -0.907032 -0.776681 -0.995498  0.722812  0.852588 -0.011156
# 14999 -0.877203 -0.815529 -0.761271 -0.996155  0.732091  0.832000  0.012918
#
# [15000 rows x 256 columns]

# %%
track_nodes = pd.read_csv('D:\\extracted_features\\tracks_256_full.csv')
track_nodes = track_nodes.set_index('track_uri')
all_nodes = pd.concat([track_nodes,playlist_nodes], axis=0)
all_nodes['id'] = all_nodes.index
all_nodes
# Out:
#                                              0         1         2         3  \
# spotify:track:000GjfnQc7ggBayDiy1sLW  0.464777 -0.125684  0.715710  0.358084
# spotify:track:000JBgYWfJQqdFaRqu2n3f  0.565548  0.048264 -0.635601  0.347392
# spotify:track:000ULyVqUhqnAyA0Um3MEH  0.097290 -0.025617 -0.640280  0.257316
# spotify:track:000VZqvXwT0YNqKk7iG2GS  0.563701 -0.095213 -0.217249 -0.281310
# spotify:track:000mA0etY38nKdvf1N04af  0.822130  0.113043  0.050832 -0.044618
# ...                                        ...       ...       ...       ...
# 14995                                 0.509209 -0.032868 -0.259281  0.576987
# 14996                                 0.532920  0.023744 -0.080581  0.642182
# 14997                                 0.438527  0.008225 -0.064779  0.618701
# 14998                                 0.579338 -0.052516 -0.360727  0.458734
# 14999                                 0.458755 -0.007124 -0.355597  0.657200
#
#                                              4         5         6         7  \
# spotify:track:000GjfnQc7ggBayDiy1sLW  0.303762  0.954011 -0.295859  0.028331
# spotify:track:000JBgYWfJQqdFaRqu2n3f  0.253677  0.982890 -0.961283 -0.019696
# spotify:track:000ULyVqUhqnAyA0Um3MEH  0.254600  0.988062 -0.963823  0.184923
# spotify:track:000VZqvXwT0YNqKk7iG2GS  0.295809  0.981444 -0.954634  0.029152
# spotify:track:000mA0etY38nKdvf1N04af  0.432734  0.974628 -0.971879 -0.043917
# ...                                        ...       ...       ...       ...
# 14995                                 0.271568  0.977360 -0.913212  0.061560
# 14996                                 0.273193  0.974883 -0.890937  0.028100
# 14997                                 0.240719  0.973851 -0.883567  0.035740
# 14998                                 0.264151  0.979575 -0.924249  0.046682
# 14999                                 0.303187  0.975179 -0.885570  0.039809
#
#                                              8         9  ...       247  \
# spotify:track:000GjfnQc7ggBayDiy1sLW -0.495248 -0.033428  ... -0.947096
# spotify:track:000JBgYWfJQqdFaRqu2n3f -0.405045 -0.009414  ... -0.837499
# spotify:track:000ULyVqUhqnAyA0Um3MEH -0.437594  0.033821  ... -0.940450
# ...                                        ...  ...       ...       ...
# 14995                                -0.450586  ... -0.120194 -0.904451
# 14996                                -0.318348  ... -0.128532 -0.891057
# 14997                                -0.477776  ... -0.120472 -0.915622
# 14998                                -0.514681  ... -0.082898 -0.879444
# 14999                                -0.288600  ... -0.111689 -0.903851
#
#                                            248       249       250       251  \
# spotify:track:000GjfnQc7ggBayDiy1sLW  0.992281 -0.958093 -0.953317 -0.917473
# spotify:track:000JBgYWfJQqdFaRqu2n3f  0.995980 -0.911891 -0.638338 -0.850850
# spotify:track:000ULyVqUhqnAyA0Um3MEH  0.988101 -0.970540 -0.871060 -0.840048
# spotify:track:000VZqvXwT0YNqKk7iG2GS  0.994377 -0.762435 -0.914978 -0.932535
# spotify:track:000mA0etY38nKdvf1N04af  0.998422 -0.863780 -0.951869 -0.879061
# ...                                        ...       ...       ...       ...
# 14995                                 0.996007 -0.853962 -0.829651 -0.785840
# 14996                                 0.996765 -0.848702 -0.856475 -0.793554
# 14997                                 0.996209 -0.861927 -0.823383 -0.751569
# 14998                                 0.997280 -0.776388 -0.907032 -0.776681
# 14999                                 0.995959 -0.877203 -0.815529 -0.761271
#
#                                            252       253       254       255
# spotify:track:000GjfnQc7ggBayDiy1sLW -0.997311  0.216808  0.580898  0.059023
# spotify:track:000JBgYWfJQqdFaRqu2n3f -0.997972  0.600172  0.876552 -0.082913
# spotify:track:000ULyVqUhqnAyA0Um3MEH -0.997457  0.465446  0.756995  0.014149
# spotify:track:000VZqvXwT0YNqKk7iG2GS -0.999104  0.015044  0.745456 -0.087516
# spotify:track:000mA0etY38nKdvf1N04af -0.997855  0.898769  0.932477 -0.217486
# ...                                        ...       ...       ...       ...
# 14995                                -0.994907  0.715587  0.847042  0.020912
# 14996                                -0.993932  0.639508  0.766159  0.043139
# 14997                                -0.996538  0.701738  0.850584  0.037790
# 14998                                -0.995498  0.722812  0.852588 -0.011156
# 14999                                -0.996155  0.732091  0.832000  0.012918
#
# [233129 rows x 257 columns]

# %%
import csv

csv_headers = ['identifier']
[csv_headers.append(i) for i in range(0, 256)]

with open('D:\\extracted_features\\all_nodes.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    
    writer.writerow(csv_headers)
    
    writer.writerows(all_nodes.values)

# %%
train_graph = pd.read_csv('D:\\extracted_features\\train_edges_graph.csv').drop('pos', axis=1)
test_graph = pd.read_csv('D:\\extracted_features\\test_edges_graph.csv').drop('pos', axis=1)

# %%
train_graph.columns = ['target', 'source']
train_graph
# Out:
#         target                                source
# 0            0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1            0  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2            0  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3            0  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4            0  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...        ...                                   ...
# 767001   14999  spotify:track:5hTpBe8h35rJ67eAWHQsJx
# 767002   14999  spotify:track:3kxfsdsCpFgN412fpnW85Y
# 767003   14999  spotify:track:6eT7xZZlB2mwyzJ2sUKG6w
# 767004   14999  spotify:track:4Q3N4Ct4zCuIHuZ65E3BD4
# 767005   14999  spotify:track:0VgkVdmE4gld66l8iyGjgx
#
# [767006 rows x 2 columns]

# %%
test_graph.columns = ['target', 'source']
test_graph
# Out:
#         target                                source
# 0            0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1            0  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2            0  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3            0  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4            0  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...        ...                                   ...
# 922430   14999  spotify:track:5hTpBe8h35rJ67eAWHQsJx
# 922431   14999  spotify:track:3kxfsdsCpFgN412fpnW85Y
# 922432   14999  spotify:track:6eT7xZZlB2mwyzJ2sUKG6w
# 922433   14999  spotify:track:4Q3N4Ct4zCuIHuZ65E3BD4
# 922434   14999  spotify:track:0VgkVdmE4gld66l8iyGjgx
#
# [922435 rows x 2 columns]

# %%
G_train = StellarGraph({'item': all_nodes} , train_graph)
print(G_train.info())

G_test = StellarGraph({'item': all_nodes} , test_graph)
print(G_test.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 233129, Edges: 767006
#
#  Node types:
#   item: [233129]
#     Features: float32 vector, length 256
#     Edge types: item-default->item
#
#  Edge types:
#     item-default->item: [767006]
#         Weights: all 1 (default)
#         Features: none
# StellarGraph: Undirected multigraph
#  Nodes: 233129, Edges: 922435
#
#  Node types:
#   item: [233129]
#     Features: float32 vector, length 256
#     Edge types: item-default->item
#
#  Edge types:
#     item-default->item: [922435]
#         Weights: all 1 (default)
#         Features: none

# %%
training_samples = pd.read_csv('D:\\extracted_features\\train_samples.csv')
testing_samples = pd.read_csv('D:\\extracted_features\\test_samples.csv')

# %%
training_labels = np.asarray(training_samples['link'].values)
testing_labels = np.asarray(testing_samples['link'].values)

# %%
training_sample_nodes = np.asarray(training_samples.values[:,:2])
testing_sample_nodes = np.asarray(testing_samples.values[:,:2])

# %%
num_samples = [10, 5]

# %%
train_gen = GraphSAGELinkGenerator(G_train, batch_size, num_samples)
test_gen = GraphSAGELinkGenerator(G_test, batch_size, num_samples)

# %%
layer_sizes = [32, 32]
graphsage = GraphSAGE(
    layer_sizes=layer_sizes, generator=train_gen, bias=True, dropout=0.2
)

# %%
x_inp, x_out = graphsage.in_out_tensors()

# %%
logits = link_classification(
    output_dim=1, output_act="linear", edge_embedding_method="ip"
)(x_out)

prediction = keras.layers.Activation(keras.activations.sigmoid)(logits)
# Out:
# link_classification: using 'ip' method to combine node embeddings into edge embeddings

# %%
model = keras.Model(inputs=x_inp, outputs=prediction)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.binary_crossentropy,
    metrics=[keras.metrics.binary_accuracy],
)

# %%
train_flow = train_gen.flow(training_sample_nodes, training_labels, shuffle=True)
test_flow = test_gen.flow(testing_sample_nodes, testing_labels)

# %%
history = model.fit(
    train_flow, epochs=10, verbose=1, shuffle=True
)
# Out:
# Epoch 1/10
# 6218/6218 [==============================] - 563s 90ms/step - loss: 0.6282 - binary_accuracy: 0.6604
# Epoch 2/10
# 6218/6218 [==============================] - 544s 88ms/step - loss: 0.5922 - binary_accuracy: 0.7095
# Epoch 3/10
# 6218/6218 [==============================] - 548s 88ms/step - loss: 0.5794 - binary_accuracy: 0.7249
# Epoch 4/10
# 6218/6218 [==============================] - 543s 87ms/step - loss: 0.5737 - binary_accuracy: 0.7318
# Epoch 5/10
# 6218/6218 [==============================] - 541s 87ms/step - loss: 0.5701 - binary_accuracy: 0.7357
# Epoch 6/10
# 6218/6218 [==============================] - 523s 84ms/step - loss: 0.5659 - binary_accuracy: 0.7412
# Epoch 7/10
# 6218/6218 [==============================] - 509s 82ms/step - loss: 0.5651 - binary_accuracy: 0.7423
# Epoch 8/10
# 6218/6218 [==============================] - 508s 82ms/step - loss: 0.5626 - binary_accuracy: 0.7462
# Epoch 9/10
# 6218/6218 [==============================] - 514s 83ms/step - loss: 0.5616 - binary_accuracy: 0.7464
# Epoch 10/10
# 6218/6218 [==============================] - 512s 82ms/step - loss: 0.5593 - binary_accuracy: 0.75003s -

# %%
train_metrics = model.evaluate(train_flow)
test_metrics = model.evaluate(test_flow)

print("\nTrain Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the trained model:")
for name, val in zip(model.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 6218/6218 [==============================] - 413s 66ms/step - loss: 0.4901 - binary_accuracy: 0.84872s - l
# 3039/3039 [==============================] - 215s 71ms/step - loss: 0.5042 - binary_accuracy: 0.82998s - loss: 0.5 - ETA: 2s
#
# Train Set Metrics of the trained model:
# 	loss: 0.4901
# 	binary_accuracy: 0.8487
#
# Test Set Metrics of the trained model:
# 	loss: 0.5042
# 	binary_accuracy: 0.8299

# %%
y_pred = model.predict(test_flow)
y_pred
# Out:
# array([[0.69759125],
#        [0.7119384 ],
#        [0.5603485 ],
#        ...,
#        [0.67303574],
#        [0.6317589 ],
#        [0.34943926]], dtype=float32)

# %%
y_predicted = []
[y_predicted.append(int(round(value[0], 0))) for value in y_pred]

from sklearn.metrics import roc_auc_score

roc_auc_score(testing_labels, y_predicted)
# Out:
# 0.8301655829625925

# %%
from sklearn.metrics import average_precision_score

average_precision_score(testing_labels, y_predicted)
# Out:
# 0.7605334689705625

# %%
GHIN_train = StellarGraph({'playlist': playlist_nodes, 'track': track_nodes} , train_graph)
print(GHIN_train.info())

GHIN_test = StellarGraph({'playlist': playlist_nodes, 'track': track_nodes} , test_graph)
print(GHIN_test.info())
# Out:
# StellarGraph: Undirected multigraph
#  Nodes: 233129, Edges: 767006
#
#  Node types:
#   track: [218129]
#     Features: float32 vector, length 256
#     Edge types: track-default->playlist
#   playlist: [15000]
#     Features: float32 vector, length 256
#     Edge types: playlist-default->track
#
#  Edge types:
#     playlist-default->track: [767006]
#         Weights: all 1 (default)
#         Features: none
# StellarGraph: Undirected multigraph
#  Nodes: 233129, Edges: 922435
#
#  Node types:
#   track: [218129]
#     Features: float32 vector, length 256
#     Edge types: track-default->playlist
#   playlist: [15000]
#     Features: float32 vector, length 256
#     Edge types: playlist-default->track
#
#  Edge types:
#     playlist-default->track: [922435]
#         Weights: all 1 (default)
#         Features: none

# %%
from stellargraph.mapper import HinSAGELinkGenerator

train_gen = HinSAGELinkGenerator(GHIN_train, batch_size, num_samples, head_node_types=["playlist", "track"])
test_gen = HinSAGELinkGenerator(GHIN_test, batch_size, num_samples, head_node_types=["playlist", "track"])

# %%
from stellargraph.layer import HinSAGE

layer_sizes = [32, 32]
hinsage = HinSAGE(
    layer_sizes=layer_sizes, generator=train_gen, bias=True, dropout=0.2
)

# %%
x_inp, x_out = hinsage.in_out_tensors()

# %%
logits = link_classification(
    output_dim=1, output_act="linear", edge_embedding_method="ip"
)(x_out)

prediction = keras.layers.Activation(keras.activations.sigmoid)(logits)
# Out:
# link_classification: using 'ip' method to combine node embeddings into edge embeddings

# %%
modelHIN = keras.Model(inputs=x_inp, outputs=prediction)

modelHIN.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.binary_crossentropy,
    metrics=[keras.metrics.binary_accuracy],
)

# %%
history2 = modelHIN.fit(
    train_flow, epochs=10, verbose=1, shuffle=True
)
# Out:
# Epoch 1/10
# 6218/6218 [==============================] - 733s 116ms/step - loss: 0.6093 - binary_accuracy: 0.6796
# Epoch 2/10
# 6218/6218 [==============================] - 512s 82ms/step - loss: 0.5654 - binary_accuracy: 0.7467
# Epoch 3/10
# 6218/6218 [==============================] - 516s 83ms/step - loss: 0.5539 - binary_accuracy: 0.7648
# Epoch 4/10
# 6218/6218 [==============================] - 464s 75ms/step - loss: 0.5475 - binary_accuracy: 0.7728
# Epoch 5/10
# 6218/6218 [==============================] - 460s 74ms/step - loss: 0.5427 - binary_accuracy: 0.7796
# Epoch 6/10
# 6218/6218 [==============================] - 460s 74ms/step - loss: 0.5374 - binary_accuracy: 0.7863
# Epoch 7/10
# 6218/6218 [==============================] - 460s 74ms/step - loss: 0.5332 - binary_accuracy: 0.7908
# Epoch 8/10
# 6218/6218 [==============================] - 514s 83ms/step - loss: 0.5303 - binary_accuracy: 0.79381s - loss: 0.5303 - binary_
# Epoch 9/10
# 6218/6218 [==============================] - 527s 85ms/step - loss: 0.5291 - binary_accuracy: 0.7944
# Epoch 10/10
# 6218/6218 [==============================] - 525s 84ms/step - loss: 0.5250 - binary_accuracy: 0.79960s - loss: 0.5250 - binary_accuracy

# %%
y_pred = modelHIN.predict(test_flow)
y_pred
# Out:
# array([[0.72315085],
#        [0.717582  ],
#        [0.72284466],
#        ...,
#        [0.527136  ],
#        [0.63651794],
#        [0.55006355]], dtype=float32)

# %%
y_predicted = []
[y_predicted.append(int(round(value[0], 0))) for value in y_pred]

roc_auc_score(testing_labels, y_predicted)
# Out:
# 0.8133637823465922

# %%
average_precision_score(testing_labels, y_predicted)
# Out:
# 0.7464333227652322

# %%
train_metrics = modelHIN.evaluate(train_flow)
test_metrics = modelHIN.evaluate(test_flow)

print("\nTrain Set Metrics of the trained model:")
for name, val in zip(modelHIN.metrics_names, train_metrics):
    print("\t{}: {:0.4f}".format(name, val))

print("\nTest Set Metrics of the trained model:")
for name, val in zip(modelHIN.metrics_names, test_metrics):
    print("\t{}: {:0.4f}".format(name, val))
# Out:
# 6218/6218 [==============================] - 423s 66ms/step - loss: 0.4847 - binary_accuracy: 0.85260s - loss: 0.4847 - binary_accurac
# 3039/3039 [==============================] - 203s 67ms/step - loss: 0.5148 - binary_accuracy: 0.8128
#
# Train Set Metrics of the trained model:
# 	loss: 0.4847
# 	binary_accuracy: 0.8526
#
# Test Set Metrics of the trained model:
# 	loss: 0.5148
# 	binary_accuracy: 0.8128
